# %%
# PACKAGES and TABLES
#collection_table ="0_coll_direct_extraction.pkl"
direc = '/Users/yerik/_apple_source/PY/JUPY/py2ms/ms_MUSIC_COLLECTION/'

# %%
exec(open(f"ms_2_music_files_export_table.py",encoding="utf-8").read())
# Out:
# ------------------------------------------------------------------------- for On DEMAND = Music_2022
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: my_folder_path
# ***df*** will be returned having ::: 101  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 1015.712
# Grand Total Size in Bytes: 1065051454.000
# Grand Total Size in GB: 0.992
#
#  FREQUENCY TABLE:::
#
#      Extension  frequency  total_size_in_mb
# 0       .mp3         79        950.068744
# 1       .jpg         12          0.221171
# 2                     8          0.005863
# 3       .wav          1         65.412533
# 4  .DS_Store          1          0.003906
#
#
#  FREQUENCY TABLE of
#
#  ['.m4a', '.mp3', '.MP3', '.Mp3', '.wav', '.WAV', '.flac', '.FLAC', '.aac', '.ogg', '.wma', '.au', '.aif', '.aiff']
#
#
#
# total music files :  80
#
#    Extension  frequency  total_size_in_mb
# 0      .mp3         79        950.068744
# 1      .wav          1         65.412533
#
#  ATTN ->
# DF with ALL files ::: df :101:: &
# DF with just audio_extensions ::: df_AU ::80:
# ------------------------------------------------------------------------- for On DEMAND = Music_2023
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: my_folder_path
# ***df*** will be returned having ::: 462  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 12924.831
# Grand Total Size in Bytes: 13552667797.000
# Grand Total Size in GB: 12.622
#
#  FREQUENCY TABLE:::
#
#      Extension  frequency  total_size_in_mb
# 0       .wav        282       8486.860006
# 1      .aiff        144       4275.668518
# 2                    20          0.025398
# 3       .mp3         10        162.202727
# 4       .jpg          4          0.066734
# 5  .DS_Store          2          0.007812
#
#
#  FREQUENCY TABLE of
#
#  ['.m4a', '.mp3', '.MP3', '.Mp3', '.wav', '.WAV', '.flac', '.FLAC', '.aac', '.ogg', '.wma', '.au', '.aif', '.aiff']
#
#
#
# total music files :  436
#
#    Extension  frequency  total_size_in_mb
# 0      .wav        282       8486.860006
# 1     .aiff        144       4275.668518
# 2      .mp3         10        162.202727
#
#  ATTN ->
# DF with ALL files ::: df :462:: &
# DF with just audio_extensions ::: df_AU ::436:
# ----------------------------------------------------------------------- for On SOURCE = source
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: my_folder_path
# ***df*** will be returned having ::: 6642  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 115958.471
# Grand Total Size in Bytes: 121591269623.000
# Grand Total Size in GB: 113.241
#
#  FREQUENCY TABLE:::
#
#     Extension  frequency  total_size_in_mb
# 0      .mp3       5640      58985.559785
# 1      .wav        600      35728.414760
# 2     .aiff        288      19322.015064
# 3                   41          0.000000
# 4      .m4a         31        666.839018
# 5      .MP3         23        247.690260
# 6      .aif         11        747.824545
# 7     .flac          8        260.127507
#
#
#  FREQUENCY TABLE of
#
#  ['.m4a', '.mp3', '.MP3', '.Mp3', '.wav', '.WAV', '.flac', '.FLAC', '.aac', '.ogg', '.wma', '.au', '.aif', '.aiff']
#
#
#
# total music files :  6601
#
#    Extension  frequency  total_size_in_mb
# 0      .mp3       5640      58985.559785
# 1      .wav        600      35728.414760
# 2     .aiff        288      19322.015064
# 3      .m4a         31        666.839018
# 4      .MP3         23        247.690260
# 5      .aif         11        747.824545
# 6     .flac          8        260.127507
#
#  ATTN ->
# DF with ALL files ::: df :6642:: &
# DF with just audio_extensions ::: df_AU ::6601:
# ----------------------------------------------------------------------- MERGED ALL df_AU_(1-3) together
#
# ATTN ::::: df_AU_ALL :::::: M22 M23 and SOURCE in one df
#
# ALL MUSIC FILES in HD_bu :: total BYTES  129898.68346691132   total music Files  7117

# %% [markdown]
# # OTHER DIRECTORY

# %%
## ATTN FOR OTHER DIRECTORIES - just uncomment this *******************

# path_songs = f'/Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1_source_DJ' 
# exec(open(f"{direc}/ms_1_music_files.py",encoding="utf-8").read()) #paths
# df_AU_ALL =df_AU.copy()
# df_AU_ALL.head()

# %%
# CLEAN
df = df_AU_ALL[~df_AU_ALL['Name'].str.startswith('._')].copy()
df = df[df['Type'] != 'Directory']

len(df)#.head()
df
# Out:
#                  Name  Type  \
# 0     LA MAMA GORDOXR  File
# 1     Boris Brejcha -  File
# 2     Massano - The F  File
# 3     WhoMadeWho - Ev  File
# 4     Claude VonStrok  File
# ...               ...   ...
# 7111  Hanz, Makzo - T  File
# 7112  fr_pieg-14_03_2  File
# 7113  01 Intro En sou  File
# 7114  [P] Walker & Ro  File
# 7115  [P] John Summit  File
#
#                                                    Path Extension  Size (MB)
# 0     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...      .wav  65.412533
# 1     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...      .mp3  19.894636
# 2     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...      .mp3  19.577145
# 3     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...      .mp3  18.569843
# 4     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...      .mp3  18.524839
# ...                                                 ...       ...        ...
# 7111  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...      .mp3   4.625304
# 7112  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...      .mp3   4.618976
# 7113  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...      .mp3   4.618972
# 7114  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...      .mp3   4.594223
# 7115  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...      .mp3   4.589869
#
# [6898 rows x 5 columns]

# %%
#df = df.head(10).copy()

# %% [markdown]
# # MAIN FUNCTIONS

# %% [markdown]
# ### QUALITATIVE

# %%
#1# COMPPUTE ---------------------- DURATION
exec(open(f"_ms_fields_1_duration.py",encoding="utf-8").read())
df['Duration'] = [get_duration(path) for path in tqdm(df['Path'], desc="DURATION:::Processing files")]

#2# COMPPUTE ---------------------- BITRATE
exec(open(f"_ms_fields_2_bitrate.py",encoding="utf-8").read());print('BITRATE :::Processing files : DONE')
df['bitrate'] = df.apply(lambda row: compute_bitrate(row['Path'], row['Duration']), axis=1)
# Out:
# DURATION:::Processing files: 100%|██████████| 6923/6923 [13:00<00:00,  8.87it/s]
# BITRATE :::Processing files : DONE

# %% [markdown]
# ### duration check

# %%
# Convert 'duration' column to numeric, coercing errors to NaN
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

# %%
# make a new variable
df['duration_minutes'] = df['Duration'] / 60
#filter songs below 2 min long
df_short_erase = df[df['duration_minutes'] < 2].copy()
#filter songs over 12 min long
df_long_erase = df[df['duration_minutes'] > 12].copy()
#filter songs within range (2,12)
df = df[(df['duration_minutes'] > 2) & (df['duration_minutes'] < 12)].copy()

# %% [markdown]
# ### bitrate check

# %%
df = df[df['bitrate'] >= 320].copy()
# erase 
df_bitrate_erase = df[df['bitrate'] < 320].copy()
print('\n\nwill be ERASE from BITRATE ::',len(df_bitrate_erase))
# Out:
# will be ERASE from BITRATE :: 0

# %%
# taking 320 bitrate as the lowest quality accepted, we move forward and export the table for futher investigation
# remember the goal of this project is to filter songs for ultimate collection where we can play without so much 
# worrying of what is the quality and DO INVESTIGATE in case you have 319 through DF_FILETERED first
print(df_bitrate_erase['bitrate'].value_counts().sort_index(ascending=True))

print('\n !!! Following will be adding after found duplicates NEXT :: ',len(df))
# Out:
# Series([], Name: bitrate, dtype: int64)
#
#  !!! Following will be adding after found duplicates NEXT ::  6923

# %%
df.head()
# Out:
#               Name  Type                                               Path  \
# 0  LA MAMA GORDOXR  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 1  Boris Brejcha -  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 2  Massano - The F  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 3  WhoMadeWho - Ev  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 4  Claude VonStrok  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
#
#   Extension  Size (MB)    Duration      bitrate  duration_minutes
# 0      .wav  65.412533  388.800000  1411.317119          6.480000
# 1      .mp3  19.894636  520.359184   320.717514          8.672653
# 2      .mp3  19.577145  512.052245   320.719211          8.534204
# 3      .mp3  18.569843  485.694694   320.726452          8.094912
# 4      .mp3  18.524839  484.519184   320.725414          8.075320

# %% [markdown]
# ### QUANTITATIVE

# %%
################################################                                       1) id TAGS
exec(open(f"{direc}/_ms_pl_info_1a_all-id-tags.py", encoding="utf-8").read())
    ################################################                                       2)  LUFS
exec(open(f"{direc}/_ms_pl_info_2_all_LUFS.py",encoding="utf-8").read())
df['lufs'] = compute_lufs_for_paths(df['Path'])
    ################################################                                       3)  BPM
exec(open(f"{direc}/_ms_pl_info_3_BPM.py",encoding="utf-8").read())
df['BPM'] = [compute_bpm(x) if x.endswith(tuple(audio_extensions)) else None for x in tqdm(df['Path'], desc="Computing BPM")]
# Out:
# Processing Files: 100%|███████████████████████| 371/371 [00:48<00:00,  7.71it/s]
# Processing WAV Files: 100%|███████████████████| 742/742 [01:33<00:00,  7.90it/s]
# Error at index 0: object of type 'TIT2' has no len()
# Error at index 225: object of type 'TDRC' has no len()
# Error at index 288: object of type 'TXXX' has no len()
# Error at index 518: object of type 'TIT2' has no len()
# Error at index 523: object of type 'TIT2' has no len()
# Error at index 527: object of type 'TIT2' has no len()
# Error at index 531: object of type 'TIT2' has no len()
# Error at index 535: object of type 'COMM' has no len()
# Error at index 539: object of type 'TIT2' has no len()
# Error at index 540: object of type 'TIT2' has no len()
# Error at index 541: object of type 'TIT2' has no len()
# Error at index 546: object of type 'COMM' has no len()
# Error at index 548: object of type 'COMM' has no len()
# Error at index 549: object of type 'COMM' has no len()
# Error at index 551: object of type 'TIT2' has no len()
# Error at index 552: object of type 'TIT2' has no len()
# Error at index 561: object of type 'COMM' has no len()
# Error at index 562: object of type 'COMM' has no len()
# Error at index 563: object of type 'TIT2' has no len()
# Error at index 564: object of type 'TIT2' has no len()
# Error at index 565: object of type 'COMM' has no len()
# Error at index 567: object of type 'TIT2' has no len()
# Error at index 568: object of type 'TIT2' has no len()
# Error at index 569: object of type 'TIT2' has no len()
# Error at index 571: object of type 'TDRC' has no len()
# Error at index 572: object of type 'TIT2' has no len()
# Error at index 573: object of type 'TIT2' has no len()
# Error at index 575: object of type 'COMM' has no len()
# Error at index 578: object of type 'TIT2' has no len()
# Error at index 582: object of type 'TIT2' has no len()
# Error at index 583: object of type 'TIT2' has no len()
# Error at index 585: object of type 'TIT2' has no len()
# Error at index 586: object of type 'TIT2' has no len()
# Error at index 588: object of type 'TIT2' has no len()
# Error at index 590: object of type 'TIT2' has no len()
# Error at index 591: object of type 'COMM' has no len()
# Error at index 592: object of type 'TIT2' has no len()
# Error at index 596: object of type 'TIT2' has no len()
# Error at index 597: object of type 'TIT2' has no len()
# Error at index 600: object of type 'TIT2' has no len()
# Error at index 604: object of type 'TIT2' has no len()
# Error at index 606: object of type 'TIT2' has no len()
# Error at index 610: object of type 'TIT2' has no len()
# Error at index 612: object of type 'TIT2' has no len()
# Error at index 614: object of type 'TIT2' has no len()
# Error at index 615: object of type 'COMM' has no len()
# Error at index 618: object of type 'TIT2' has no len()
# Error at index 625: object of type 'TIT2' has no len()
# Error at index 626: object of type 'TIT2' has no len()
# Error at index 628: object of type 'TIT2' has no len()
# Error at index 631: object of type 'TIT2' has no len()
# Error at index 634: object of type 'TIT2' has no len()
# Error at index 635: object of type 'TIT2' has no len()
# Error at index 636: object of type 'COMM' has no len()
# Error at index 637: object of type 'TIT2' has no len()
# Error at index 641: object of type 'TIT2' has no len()
# Error at index 642: object of type 'TIT2' has no len()
# Error at index 643: object of type 'TIT2' has no len()
# Error at index 644: object of type 'TIT2' has no len()
# Error at index 646: object of type 'TIT2' has no len()
# Error at index 648: object of type 'COMM' has no len()
# Error at index 649: object of type 'TIT2' has no len()
# Error at index 652: object of type 'TIT2' has no len()
# Error at index 653: object of type 'TIT2' has no len()
# Error at index 656: object of type 'COMM' has no len()
# Error at index 659: object of type 'TIT2' has no len()
# Error at index 660: object of type 'TIT2' has no len()
# Error at index 662: object of type 'TIT2' has no len()
# Error at index 664: object of type 'TIT2' has no len()
# Error at index 666: object of type 'TIT2' has no len()
# Error at index 667: object of type 'TIT2' has no len()
# Error at index 670: object of type 'COMM' has no len()
# Error at index 672: object of type 'TIT2' has no len()
# Error at index 680: object of type 'TIT2' has no len()
# Error at index 681: object of type 'TIT2' has no len()
# Error at index 683: object of type 'TIT2' has no len()
# Error at index 684: object of type 'TIT2' has no len()
# Error at index 686: object of type 'TIT2' has no len()
# Error at index 688: object of type 'TIT2' has no len()
# Error at index 690: object of type 'TIT2' has no len()
# Error at index 693: object of type 'TIT2' has no len()
# Error at index 694: object of type 'TIT2' has no len()
# Error at index 695: object of type 'TIT2' has no len()
# Error at index 696: object of type 'TIT2' has no len()
# Error at index 697: object of type 'TIT2' has no len()
# Error at index 703: object of type 'TIT2' has no len()
# Error at index 705: object of type 'TIT2' has no len()
# Error at index 706: object of type 'TIT2' has no len()
# Error at index 708: object of type 'TIT2' has no len()
# Error at index 710: object of type 'TIT2' has no len()
# Error at index 711: object of type 'COMM' has no len()
# Error at index 714: object of type 'TIT2' has no len()
# Error at index 715: object of type 'TIT2' has no len()
# Error at index 717: object of type 'COMM' has no len()
# Error at index 719: object of type 'TIT2' has no len()
# Error at index 720: object of type 'TIT2' has no len()
# Error at index 722: object of type 'TIT2' has no len()
# Error at index 724: object of type 'TIT2' has no len()
# Error at index 725: object of type 'TIT2' has no len()
# Error at index 726: object of type 'COMM' has no len()
# Error at index 728: object of type 'TIT2' has no len()
# Error at index 730: object of type 'TIT2' has no len()
# Error at index 731: object of type 'TIT2' has no len()
# Error at index 733: object of type 'TIT2' has no len()
# Error at index 734: object of type 'TIT2' has no len()
# Error at index 735: object of type 'TIT2' has no len()
# Error at index 736: object of type 'COMM' has no len()
# Error at index 737: object of type 'TIT2' has no len()
# Error at index 741: object of type 'TIT2' has no len()
# Error at index 742: object of type 'TIT2' has no len()
# Error at index 743: object of type 'TIT2' has no len()
# Error at index 745: object of type 'TIT2' has no len()
# Error at index 746: object of type 'TIT2' has no len()
# Error at index 747: object of type 'TIT2' has no len()
# Error at index 748: object of type 'TIT2' has no len()
# Error at index 750: object of type 'TIT2' has no len()
# Error at index 752: object of type 'TIT2' has no len()
# Error at index 753: object of type 'TIT2' has no len()
# Error at index 754: object of type 'COMM' has no len()
# Error at index 755: object of type 'TIT2' has no len()
# Error at index 756: object of type 'TIT2' has no len()
# Error at index 757: object of type 'TIT2' has no len()
# Error at index 758: object of type 'TIT2' has no len()
# Error at index 760: object of type 'TIT2' has no len()
# Error at index 761: object of type 'TIT2' has no len()
# Error at index 762: object of type 'COMM' has no len()
# Error at index 763: object of type 'TIT2' has no len()
# Error at index 764: object of type 'COMM' has no len()
# Error at index 765: object of type 'COMM' has no len()
# Error at index 766: object of type 'TIT2' has no len()
# Error at index 767: object of type 'TIT2' has no len()
# Error at index 770: object of type 'TIT2' has no len()
# Error at index 771: object of type 'TIT2' has no len()
# Error at index 772: object of type 'TIT2' has no len()
# Error at index 773: object of type 'TIT2' has no len()
# Error at index 774: object of type 'TIT2' has no len()
# Error at index 775: object of type 'TIT2' has no len()
# Error at index 777: object of type 'TIT2' has no len()
# Error at index 779: object of type 'TIT2' has no len()
# Error at index 783: object of type 'TIT2' has no len()
# Error at index 786: object of type 'TIT2' has no len()
# Error at index 787: object of type 'COMM' has no len()
# Error at index 789: object of type 'TIT2' has no len()
# Error at index 790: object of type 'COMM' has no len()
# Error at index 791: object of type 'TIT2' has no len()
# Error at index 793: object of type 'TIT2' has no len()
# Error at index 794: object of type 'TIT2' has no len()
# Error at index 799: object of type 'TIT2' has no len()
# Error at index 800: object of type 'TIT2' has no len()
# Error at index 801: object of type 'TIT2' has no len()
# Error at index 802: object of type 'TIT2' has no len()
# Error at index 803: object of type 'TIT2' has no len()
# Error at index 804: object of type 'COMM' has no len()
# Error at index 805: object of type 'TIT2' has no len()
# Error at index 806: object of type 'TIT2' has no len()
# Error at index 807: object of type 'TIT2' has no len()
# Error at index 808: object of type 'TIT2' has no len()
# Error at index 809: object of type 'TIT2' has no len()
# Error at index 816: object of type 'TIT2' has no len()
# Error at index 818: object of type 'TIT2' has no len()
# Error at index 819: object of type 'TIT2' has no len()
# Error at index 820: object of type 'TIT2' has no len()
# Error at index 821: object of type 'TIT2' has no len()
# Error at index 828: object of type 'TIT2' has no len()
# Error at index 829: object of type 'TIT2' has no len()
# Error at index 830: object of type 'TIT2' has no len()
# Error at index 831: object of type 'TIT2' has no len()
# Error at index 835: object of type 'TIT2' has no len()
# Error at index 836: object of type 'TIT2' has no len()
# Error at index 837: object of type 'TIT2' has no len()
# Error at index 840: object of type 'TIT2' has no len()
# Error at index 841: object of type 'TIT2' has no len()
# Error at index 842: object of type 'COMM' has no len()
# Error at index 843: object of type 'TIT2' has no len()
# Error at index 844: object of type 'TIT2' has no len()
# Error at index 845: object of type 'TIT2' has no len()
# Error at index 848: object of type 'TIT2' has no len()
# Error at index 849: object of type 'TIT2' has no len()
# Error at index 850: object of type 'TIT2' has no len()
# Error at index 853: object of type 'TIT2' has no len()
# Error at index 856: object of type 'TIT2' has no len()
# Error at index 859: object of type 'COMM' has no len()
# Error at index 860: object of type 'COMM' has no len()
# Error at index 861: object of type 'TIT2' has no len()
# Error at index 865: object of type 'TIT2' has no len()
# Error at index 868: object of type 'TIT2' has no len()
# Error at index 870: object of type 'TIT2' has no len()
# Error at index 873: object of type 'TIT2' has no len()
# Error at index 874: object of type 'TIT2' has no len()
# Error at index 875: object of type 'TIT2' has no len()
# Error at index 876: object of type 'TIT2' has no len()
# Error at index 878: object of type 'TIT2' has no len()
# Error at index 879: object of type 'TIT2' has no len()
# Error at index 881: object of type 'TIT2' has no len()
# Error at index 882: object of type 'TIT2' has no len()
# Error at index 883: object of type 'TIT2' has no len()
# Error at index 884: object of type 'COMM' has no len()
# Error at index 885: object of type 'TIT2' has no len()
# Error at index 886: object of type 'TIT2' has no len()
# Error at index 887: object of type 'TIT2' has no len()
# Error at index 888: object of type 'TIT2' has no len()
# Error at index 889: object of type 'TIT2' has no len()
# Error at index 890: object of type 'TIT2' has no len()
# Error at index 891: object of type 'TIT2' has no len()
# Error at index 894: object of type 'TIT2' has no len()
# Error at index 895: object of type 'TIT2' has no len()
# Error at index 901: object of type 'TIT2' has no len()
# Error at index 902: object of type 'TIT2' has no len()
# Error at index 904: object of type 'COMM' has no len()
# Error at index 905: object of type 'TIT2' has no len()
# Error at index 906: object of type 'TDRC' has no len()
# Error at index 910: object of type 'TIT2' has no len()
# Error at index 911: object of type 'TIT2' has no len()
# Error at index 912: object of type 'TIT2' has no len()
# Error at index 913: object of type 'COMM' has no len()
# Error at index 915: object of type 'COMM' has no len()
# Error at index 916: object of type 'TIT2' has no len()
# Error at index 917: object of type 'TIT2' has no len()
# Error at index 918: object of type 'TIT2' has no len()
# Error at index 919: object of type 'TIT2' has no len()
# Error at index 920: object of type 'TIT2' has no len()
# Error at index 921: object of type 'TIT2' has no len()
# Error at index 922: object of type 'TIT2' has no len()
# Error at index 923: object of type 'TIT2' has no len()
# Error at index 924: object of type 'TIT2' has no len()
# Error at index 926: object of type 'COMM' has no len()
# Error at index 929: object of type 'TIT2' has no len()
# Error at index 931: object of type 'TIT2' has no len()
# Error at index 932: object of type 'TIT2' has no len()
# Error at index 933: object of type 'TIT2' has no len()
# Error at index 934: object of type 'TIT2' has no len()
# Error at index 935: object of type 'TIT2' has no len()
# Error at index 936: object of type 'TIT2' has no len()
# Error at index 937: object of type 'TIT2' has no len()
# Error at index 938: object of type 'TIT2' has no len()
# Error at index 939: object of type 'TIT2' has no len()
# Error at index 941: object of type 'COMM' has no len()
# Error at index 943: object of type 'TIT2' has no len()
# Error at index 944: object of type 'TIT2' has no len()
# Error at index 946: object of type 'TIT2' has no len()
# Error at index 947: object of type 'TIT2' has no len()
# Error at index 948: object of type 'TIT2' has no len()
# Error at index 949: object of type 'TIT2' has no len()
# Error at index 952: object of type 'TIT2' has no len()
# Error at index 953: object of type 'TIT2' has no len()
# Error at index 954: object of type 'TIT2' has no len()
# Error at index 958: object of type 'TIT2' has no len()
# Error at index 959: object of type 'TIT2' has no len()
# Error at index 961: object of type 'TIT2' has no len()
# Error at index 962: object of type 'TIT2' has no len()
# Error at index 963: object of type 'TIT2' has no len()
# Error at index 965: object of type 'TIT2' has no len()
# Error at index 966: object of type 'TIT2' has no len()
# Error at index 968: object of type 'TIT2' has no len()
# Error at index 969: object of type 'TIT2' has no len()
# Error at index 970: object of type 'TIT2' has no len()
# Error at index 971: object of type 'TIT2' has no len()
# Error at index 972: object of type 'TIT2' has no len()
# Error at index 973: object of type 'TIT2' has no len()
# Error at index 974: object of type 'TIT2' has no len()
# Error at index 977: object of type 'TIT2' has no len()
# Error at index 980: object of type 'TIT2' has no len()
# Error at index 982: object of type 'TIT2' has no len()
# Error at index 984: object of type 'TIT2' has no len()
# Error at index 985: object of type 'TIT2' has no len()
# Error at index 988: object of type 'TIT2' has no len()
# Error at index 989: object of type 'TIT2' has no len()
# Error at index 993: object of type 'TIT2' has no len()
# Error at index 994: object of type 'TIT2' has no len()
# Error at index 996: object of type 'TIT2' has no len()
# Error at index 997: object of type 'TIT2' has no len()
# Error at index 998: object of type 'TIT2' has no len()
# Error at index 999: object of type 'TIT2' has no len()
# Error at index 1000: object of type 'COMM' has no len()
# Error at index 1001: object of type 'TIT2' has no len()
# Error at index 1002: object of type 'TIT2' has no len()
# Error at index 1004: object of type 'TIT2' has no len()
# Error at index 1006: object of type 'TIT2' has no len()
# Error at index 1008: object of type 'TIT2' has no len()
# Error at index 1009: object of type 'TIT2' has no len()
# Error at index 1010: object of type 'TIT2' has no len()
# Error at index 1011: object of type 'TIT2' has no len()
# Error at index 1012: object of type 'TIT2' has no len()
# Error at index 1013: object of type 'TIT2' has no len()
# Error at index 1015: object of type 'TIT2' has no len()
# Error at index 1016: object of type 'TIT2' has no len()
# Error at index 1017: object of type 'COMM' has no len()
# Error at index 1020: object of type 'TIT2' has no len()
# Error at index 1021: object of type 'TIT2' has no len()
# Error at index 1022: object of type 'TIT2' has no len()
# Error at index 1023: object of type 'TIT2' has no len()
# Error at index 1025: object of type 'TIT2' has no len()
# Error at index 1026: object of type 'TIT2' has no len()
# Error at index 1027: object of type 'TIT2' has no len()
# Error at index 1028: object of type 'TIT2' has no len()
# Error at index 1029: object of type 'TIT2' has no len()
# Error at index 1030: object of type 'TIT2' has no len()
# Error at index 1031: object of type 'TIT2' has no len()
# Error at index 1032: object of type 'TPE1' has no len()
# Error at index 1036: object of type 'TIT2' has no len()
# Error at index 1043: object of type 'TIT2' has no len()
# Error at index 1044: object of type 'TIT2' has no len()
# Error at index 1046: object of type 'TIT2' has no len()
# Error at index 1047: object of type 'TIT2' has no len()
# Error at index 1048: object of type 'TIT2' has no len()
# Error at index 1050: object of type 'TIT2' has no len()
# Error at index 1052: object of type 'TIT2' has no len()
# Error at index 1053: object of type 'TIT2' has no len()
# Error at index 1054: object of type 'TIT2' has no len()
# Error at index 1055: object of type 'TIT2' has no len()
# Error at index 1056: object of type 'TIT2' has no len()
# Error at index 1057: object of type 'TIT2' has no len()
# Error at index 1058: object of type 'TIT2' has no len()
# Error at index 1059: object of type 'TIT2' has no len()
# Error at index 1060: object of type 'TIT2' has no len()
# Error at index 1061: object of type 'TIT2' has no len()
# Error at index 1062: object of type 'TIT2' has no len()
# Error at index 1063: object of type 'TIT2' has no len()
# Error at index 1064: object of type 'TIT2' has no len()
# Error at index 1072: object of type 'TIT2' has no len()
# Error at index 1073: object of type 'TIT2' has no len()
# Error at index 1074: object of type 'COMM' has no len()
# Error at index 1076: object of type 'TIT2' has no len()
# Error at index 1077: object of type 'TIT2' has no len()
# Error at index 1078: object of type 'COMM' has no len()
# Error at index 1079: object of type 'TIT2' has no len()
# Error at index 1080: object of type 'TIT2' has no len()
# Error at index 1082: object of type 'TIT2' has no len()
# Error at index 1085: object of type 'TIT2' has no len()
# Error at index 1086: object of type 'TIT2' has no len()
# Error at index 1087: object of type 'TIT2' has no len()
# Error at index 1089: object of type 'TIT2' has no len()
# Error at index 1090: object of type 'TIT2' has no len()
# Error at index 1091: object of type 'TIT2' has no len()
# Error at index 1092: object of type 'TIT2' has no len()
# Error at index 1093: object of type 'TIT2' has no len()
# Error at index 1096: object of type 'TIT2' has no len()
# Error at index 1097: object of type 'TIT2' has no len()
# Error at index 1099: object of type 'TIT2' has no len()
# Error at index 1100: object of type 'TIT2' has no len()
# Error at index 1101: object of type 'TIT2' has no len()
# Error at index 1102: object of type 'TIT2' has no len()
# Error at index 1107: object of type 'TIT2' has no len()
# Error at index 1109: object of type 'TIT2' has no len()
# Error at index 1111: object of type 'TIT2' has no len()
# Error at index 1112: object of type 'COMM' has no len()
# Error at index 1115: object of type 'TIT2' has no len()
# Error at index 1116: object of type 'TIT2' has no len()
# Error at index 1117: object of type 'TIT2' has no len()
# Error at index 1118: object of type 'TIT2' has no len()
# Error at index 1119: object of type 'TIT2' has no len()
# Error at index 1120: object of type 'TIT2' has no len()
# Error at index 1122: object of type 'TIT2' has no len()
# Error at index 1124: object of type 'TXXX' has no len()
# Error at index 1125: object of type 'TIT2' has no len()
# Error at index 1126: object of type 'TIT2' has no len()
# Error at index 1129: object of type 'TIT2' has no len()
# Error at index 1130: object of type 'TIT2' has no len()
# Error at index 1131: object of type 'TIT2' has no len()
# Error at index 1134: object of type 'TIT2' has no len()
# Error at index 1136: object of type 'TIT2' has no len()
# Error at index 1137: object of type 'COMM' has no len()
# Error at index 1138: object of type 'TIT2' has no len()
# Error at index 1140: object of type 'TIT2' has no len()
# Error at index 1141: object of type 'TIT2' has no len()
# Error at index 1142: object of type 'TIT2' has no len()
# Error at index 1143: object of type 'TIT2' has no len()
# Error at index 1144: object of type 'TIT2' has no len()
# Error at index 1145: object of type 'TIT2' has no len()
# Error at index 1147: object of type 'TIT2' has no len()
# Error at index 1148: object of type 'TIT2' has no len()
# Error at index 1149: object of type 'TIT2' has no len()
# Error at index 1150: object of type 'COMM' has no len()
# Error at index 1151: object of type 'TIT2' has no len()
# Error at index 1152: object of type 'TIT2' has no len()
# Error at index 1153: object of type 'TIT2' has no len()
# Error at index 1154: object of type 'TIT2' has no len()
# Error at index 1155: object of type 'TIT2' has no len()
# Error at index 1156: object of type 'TIT2' has no len()
# Error at index 1157: object of type 'TIT2' has no len()
# Error at index 1160: object of type 'TIT2' has no len()
# Error at index 1162: object of type 'TIT2' has no len()
# Error at index 1163: object of type 'TIT2' has no len()
# Error at index 1164: object of type 'COMM' has no len()
# Error at index 1165: object of type 'TIT2' has no len()
# Error at index 1166: object of type 'TIT2' has no len()
# Error at index 1167: object of type 'TIT2' has no len()
# Error at index 1168: object of type 'TIT2' has no len()
# Error at index 1171: object of type 'TIT2' has no len()
# Error at index 1173: object of type 'TIT2' has no len()
# Error at index 1174: object of type 'TIT2' has no len()
# Error at index 1176: object of type 'TIT2' has no len()
# Error at index 1177: object of type 'TIT2' has no len()
# Error at index 1178: object of type 'TIT2' has no len()
# Error at index 1179: object of type 'TIT2' has no len()
# Error at index 1180: object of type 'TIT2' has no len()
# Error at index 1181: object of type 'TIT2' has no len()
# Error at index 1184: object of type 'TIT2' has no len()
# Error at index 1185: object of type 'TIT2' has no len()
# Error at index 1186: object of type 'TIT2' has no len()
# Error at index 1189: object of type 'TIT2' has no len()
# Error at index 1190: object of type 'TIT2' has no len()
# Error at index 1191: object of type 'TIT2' has no len()
# Error at index 1193: object of type 'TIT2' has no len()
# Error at index 1194: object of type 'TIT2' has no len()
# Error at index 1195: object of type 'TIT2' has no len()
# Error at index 1196: object of type 'TIT2' has no len()
# Error at index 1198: object of type 'COMM' has no len()
# Error at index 1199: object of type 'TIT2' has no len()
# Error at index 1200: object of type 'COMM' has no len()
# Error at index 1201: object of type 'TIT2' has no len()
# Error at index 1202: object of type 'TIT2' has no len()
# Error at index 1203: object of type 'TIT2' has no len()
# Error at index 1204: object of type 'TIT2' has no len()
# Error at index 1205: object of type 'TIT2' has no len()
# Error at index 1206: object of type 'TIT2' has no len()
# Error at index 1208: object of type 'TIT2' has no len()
# Error at index 1209: object of type 'TIT2' has no len()
# Error at index 1210: object of type 'TIT2' has no len()
# Error at index 1215: object of type 'TIT2' has no len()
# Error at index 1217: object of type 'COMM' has no len()
# Error at index 1218: object of type 'TIT2' has no len()
# Error at index 1219: object of type 'TIT2' has no len()
# Error at index 1222: object of type 'TIT2' has no len()
# Error at index 1223: object of type 'TIT2' has no len()
# Error at index 1224: object of type 'TIT2' has no len()
# Error at index 1227: object of type 'TIT2' has no len()
# Error at index 1228: object of type 'TIT2' has no len()
# Error at index 1229: object of type 'TIT2' has no len()
# Error at index 1230: object of type 'TIT2' has no len()
# Error at index 1231: object of type 'TIT2' has no len()
# Error at index 1232: object of type 'TIT2' has no len()
# Error at index 1233: object of type 'TIT2' has no len()
# Error at index 1236: object of type 'TIT2' has no len()
# Error at index 1237: object of type 'TIT2' has no len()
# Error at index 1241: object of type 'TIT2' has no len()
# Error at index 1242: object of type 'TIT2' has no len()
# Error at index 1243: object of type 'TIT2' has no len()
# Error at index 1248: object of type 'TIT2' has no len()
# Error at index 1249: object of type 'TIT2' has no len()
# Error at index 1250: object of type 'TIT2' has no len()
# Error at index 1253: object of type 'TIT2' has no len()
# Error at index 1254: object of type 'TIT2' has no len()
# Error at index 1257: object of type 'TIT2' has no len()
# Error at index 1258: object of type 'TIT2' has no len()
# Error at index 1261: object of type 'TIT2' has no len()
# Error at index 1262: object of type 'TIT2' has no len()
# Error at index 1263: object of type 'TIT2' has no len()
# Error at index 1264: object of type 'TIT2' has no len()
# Error at index 1265: object of type 'TIT2' has no len()
# Error at index 1266: object of type 'TIT2' has no len()
# Error at index 1267: object of type 'TIT2' has no len()
# Error at index 1268: object of type 'TIT2' has no len()
# Error at index 1269: object of type 'TIT2' has no len()
# Error at index 1270: object of type 'TIT2' has no len()
# Error at index 1271: object of type 'TIT2' has no len()
# Error at index 1272: object of type 'TIT2' has no len()
# Error at index 1273: object of type 'TIT2' has no len()
# Error at index 1274: object of type 'TIT2' has no len()
# Error at index 1277: object of type 'TIT2' has no len()
# Error at index 1278: object of type 'TIT2' has no len()
# Error at index 1279: object of type 'TIT2' has no len()
# Error at index 1280: object of type 'TIT2' has no len()
# Error at index 1281: object of type 'TIT2' has no len()
# Error at index 1285: object of type 'TIT2' has no len()
# Error at index 1289: object of type 'TIT2' has no len()
# Error at index 1290: object of type 'TIT2' has no len()
# Error at index 1291: object of type 'TIT2' has no len()
# Error at index 1292: object of type 'TIT2' has no len()
# Error at index 1294: object of type 'TIT2' has no len()
# Error at index 1295: object of type 'TIT2' has no len()
# Error at index 1296: object of type 'TIT2' has no len()
# Error at index 1297: object of type 'TIT2' has no len()
# Error at index 1298: object of type 'TIT2' has no len()
# Error at index 1302: object of type 'TIT2' has no len()
# Error at index 1307: object of type 'TIT2' has no len()
# Error at index 1309: object of type 'TIT2' has no len()
# Error at index 1311: object of type 'TIT2' has no len()
# Error at index 1313: object of type 'TIT2' has no len()
# Error at index 1314: object of type 'TIT2' has no len()
# Error at index 1316: object of type 'TIT2' has no len()
# Error at index 1319: object of type 'TIT2' has no len()
# Error at index 1320: object of type 'TIT2' has no len()
# Error at index 1322: object of type 'TIT2' has no len()
# Error at index 1325: object of type 'TIT2' has no len()
# Error at index 1326: object of type 'COMM' has no len()
# Error at index 1329: object of type 'TIT2' has no len()
# Error at index 1333: object of type 'TIT2' has no len()
# Error at index 1336: object of type 'TIT2' has no len()
# Error at index 1337: object of type 'TIT2' has no len()
# Error at index 1338: object of type 'TIT2' has no len()
# Error at index 1339: object of type 'TIT2' has no len()
# Error at index 1340: object of type 'TIT2' has no len()
# Error at index 1342: object of type 'TIT2' has no len()
# Error at index 1343: object of type 'TIT2' has no len()
# Error at index 1344: object of type 'TIT2' has no len()
# Error at index 1346: object of type 'TIT2' has no len()
# Error at index 1350: object of type 'TIT2' has no len()
# Error at index 1353: object of type 'TIT2' has no len()
# Error at index 1354: object of type 'TIT2' has no len()
# Error at index 1358: object of type 'TIT2' has no len()
# Error at index 1362: object of type 'TIT2' has no len()
# Error at index 1363: object of type 'TIT2' has no len()
# Error at index 1366: object of type 'TIT2' has no len()
# Error at index 1367: object of type 'TIT2' has no len()
# Error at index 1368: object of type 'TIT2' has no len()
# Error at index 1371: object of type 'TIT2' has no len()
# Error at index 1373: object of type 'COMM' has no len()
# Error at index 1378: object of type 'TIT2' has no len()
# Error at index 1379: object of type 'TIT2' has no len()
# Error at index 1380: object of type 'TIT2' has no len()
# Error at index 1383: object of type 'TIT2' has no len()
# Error at index 1386: object of type 'TIT2' has no len()
# Error at index 1391: object of type 'TIT2' has no len()
# Error at index 1394: object of type 'TIT2' has no len()
# Error at index 1395: object of type 'COMM' has no len()
# Error at index 1398: object of type 'TIT2' has no len()
# Error at index 1399: object of type 'TIT2' has no len()
# Error at index 1400: object of type 'TIT2' has no len()
# Error at index 1403: object of type 'TIT2' has no len()
# Error at index 1405: object of type 'COMM' has no len()
# Error at index 1411: object of type 'TIT2' has no len()
# Error at index 1424: object of type 'TIT2' has no len()
# Error at index 1425: object of type 'COMM' has no len()
# Error at index 1434: object of type 'TIT2' has no len()
# Error at index 1435: object of type 'TIT2' has no len()
# Error at index 1440: object of type 'TIT2' has no len()
# Error at index 1441: object of type 'TIT2' has no len()
# Error at index 1452: object of type 'TIT2' has no len()
# Error at index 1453: object of type 'TIT2' has no len()
# Error at index 1456: object of type 'TIT2' has no len()
# Error at index 1465: object of type 'TIT2' has no len()
# Error at index 1473: object of type 'TIT2' has no len()
# Error at index 1475: object of type 'TIT2' has no len()
# Processing MP3 Files: 100%|█████████████████| 5771/5771 [12:22<00:00,  7.77it/s]
# Processing FLAC Files: 100%|██████████████████████| 8/8 [00:00<00:00,  8.34it/s]
# Processing M4A Files: 100%|█████████████████████| 31/31 [00:06<00:00,  5.03it/s]
# ID tags registered
# Computing LUFS: 100%|███████████████████| 6923/6923 [2:58:49<00:00,  1.55s/file]
# Computing BPM:  17%|████▏                   | 1200/6923 [12:43<44:38,  2.14it/s]
# Error processing file /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0_source_DJ_ON-DEMAND/Music_2023/DJ 24/Rio Japura na Paulicéia.mp3: AUBIO ERROR: source_wavread: Failed opening /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0_source_DJ_ON-DEMAND/Music_2023/DJ 24/Rio Japura na Paulicéia.mp3 (could not find RIFF header)
# Computing BPM:  17%|███▊                  | 1206/6923 [12:50<1:17:57,  1.22it/s]
# Error processing file /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1_source_DJ/friends_NATHAN_2/Drunk.mp3: AUBIO ERROR: source_wavread: Failed opening /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1_source_DJ/friends_NATHAN_2/Drunk.mp3 (could not find RIFF header)
# Error processing file /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1_source_DJ/after_dupl_surprise_009/Drunk_2_0.mp3: AUBIO ERROR: source_wavread: Failed opening /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1_source_DJ/after_dupl_surprise_009/Drunk_2_0.mp3 (could not find RIFF header)
# Computing BPM: 100%|██████████████████████| 6923/6923 [1:39:15<00:00,  1.16it/s]

# %%
df.head()
# Out:
#               Name  Type Extension  Size (MB)      bitrate    Duration  \
# 0  Eye_Nyam_Nam_Me  File     .aiff  94.898247  1411.795090  563.866667
# 1      At_Les.aiff  File     .aiff  93.252670  1412.021834  554.000000
# 2  Night_Clubbing-  File     .aiff  84.705515  1412.383684  503.093719
# 3  Never_Come_Back  File     .aiff  81.183163  1461.598861  465.937506
# 4  Let's_Dream-BY-  File     .aiff  79.475306  1411.889106  472.195147
#
#    duration_minutes                                               Path  \
# 0          9.397778  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 1          9.233333  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 2          8.384895  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 3          7.765625  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 4          7.869919  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
#
#                                          idt_title  \
# 0  Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Blend)
# 1       At Les (Christian Smith's Hypnotica Remix)
# 2              Night Clubbing (Marko Nastic Remix)
# 3                 Never Come Back (Four Tet Remix)
# 4                       Let's Dream (Original Mix)
#
#                                idt_artist  \
# 0  Pat Thomas, Ebo Taylor, Henrik Schwarz
# 1                              Carl Craig
# 2                               Johnny D.
# 3                                 Caribou
# 4                              Paco Osuna
#
#                                          idt_album    idt_year idt_track  \
# 0  Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Mixes)  2015-09-18         1
# 1                 At Les (Christian Smith Remixes)  2010-05-24         2
# 2                                Night Clubbing EP        2015         2
# 3                                 Suddenly Remixes        2021         2
# 4                                        Long Play        2014         1
#
#                       idt_genre                            idt_comment  \
# 0                         House  engID3v1 CommentPurchased at Beatport
# 1  Techno (Peak Time / Driving)  engID3v1 CommentPurchased at Beatport
# 2                    Deep House  engID3v1 CommentPurchased at Beatport
# 3        Melodic House & Techno  engID3v1 CommentPurchased at Beatport
# 4                    Tech House  engID3v1 CommentPurchased at Beatport
#
#    idt_audio_offset    lufs         BPM
# 0              46.0 -11.431  124.917720
# 1              46.0  -8.679  126.938051
# 2              46.0  -8.688  127.003650
# 3              46.0 -10.715  128.999409
# 4              46.0  -8.718  123.910002

# %% [markdown]
# # INVESTIGATE for DUPLICATES

# %%
# Make DF the same for identifier

df['Size (MB) id'] = df['Size (MB)'].astype(str)
df['file_id'] = df['Name']+ '-MB-' +df['Size (MB) id']+ df['Extension']

# CHECK UNIQUE and/repeated
# Rows without duplicated SHA256 values (keeping only the first occurrence)
df_unique = df[~df['file_id'].duplicated(keep='first')].copy()
    
    # Rows with duplicated SHA256 values (excluding the first occurrence)
df_duplicates = df[df['file_id'].duplicated(keep='first')]

print('UNIQUE & DUPLICATES based on New name' )
print('UNIQUE     :::',len(df_unique), '  \nDUPLICATES :::' ,len(df_duplicates))
# Out:
# UNIQUE & DUPLICATES based on New name
# UNIQUE     ::: 6898
# DUPLICATES ::: 25

# %% [markdown]
# # ERASE ( 1) The ones that did not pass quality CHECK (2) DUPLICATES

# %% [markdown]
# ### move

# %%
import shutil
import pandas as pd

def move_files(df, destination):
    """
    Move files from the 'Path' column of the dataframe to the specified destination.
    """
    for file_path in tqdm(df['Path'], desc="Moving files", unit="file"):
        try:
            shutil.copy(file_path, destination)
        except Exception as e:
            print(f"Error moving {file_path} to {destination}: {e}")


# Move files based on the dataframe's intended destination

# e_1_a # BITRATE erase to UNWANTED SONGS  "Music_misc/UNWANTED_songs"
move_files(df_bitrate_erase, "/Volumes/HD_back_UP/ALL_MUSIC/Music_misc/UNWANTED_songs")

# e_1_b # DURATION erase

# send to possible PRODUCTION MATERIAL "_2_source_PROD/PROD_check"
move_files(df_short_erase, "/Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_2_source_PROD/PROD_check")
# send to possible SETS to keep         "_4_SETS/SETS_check"
move_files(df_long_erase, "/Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_4_SETS/SETS_check")

# e_2 # DUPLICATES
move_files(df_duplicates, "/Volumes/HD_back_UP/ALL_MUSIC/Music_misc/UNWANTED_songs/_DUPLICATES")
# Out:
# Moving files: 0file [00:00, ?file/s]
# Moving files: 0file [00:00, ?file/s]
# Moving files: 0file [00:00, ?file/s]
# Moving files: 100%|███████████████████████████| 25/25 [00:14<00:00,  1.76file/s]

# %% [markdown]
# ## erase

# %%
df_duplicates
# Out:
#                  Name  Type Extension  Size (MB)     bitrate    Duration  \
# 1377  Rennz - My Hous  File      .mp3  18.126552  320.017628  475.150500
# 1447  Nelly Furtado -  File      .mp3  17.291194  320.019539  453.250600
# 1495  Micky More & An  File      .mp3  16.849772  322.938111  437.688000
# 1657  Grant Nelson, S  File      .mp3  15.765529  320.040930  413.231020
# 2026  RADIUM - 08 - B  File      .mp3  14.142234  320.043315  370.680000
# 2153  Game Boys - Tet  File      .mp3  13.779521  320.023721  361.195100
# 2171  Luz1e - Surge-1  File      .mp3  13.738665  320.047001  360.097959
# 2315  Dolly Parton -   File      .mp3  13.280363  320.050670  348.081633
# 2365  Cour T. - Black  File      .mp3  13.103898  320.049255  343.457959
# 2643  Gay Marvine - M  File      .mp3  12.325850  320.050269  323.064000
# 2940  Skrillex - Stil  File      .mp3  11.570296  320.055784  303.255510
# 3020  15_peachlyfe_-_  File      .mp3  11.348527  320.069525  297.430204
# 3310  063 - Smokin' B  File      .mp3  10.765744  320.074541  282.151800
# 4766  DB7 - TETRIS TH  File      .mp3   8.866814  320.036866  232.411425
# 5140  Dee-Lite - What  File      .mp3   8.427585  320.085147  220.865306
# 5314  Fred again.. fe  File      .mp3   8.244006  320.078348  216.058776
# 5355  Diplo feat. Eld  File      .mp3   8.205143  320.078720  215.040000
# 5800  DNBN - Tetris m  File      .mp3   7.657072  320.042691  200.698775
# 6094  Skrillex & BEAM  File      .mp3   7.262069  320.085372  190.320000
# 6176  Skrillex & Bobb  File      .mp3   7.152845  320.090229  187.454694
# 6203  Pete Tong & Bec  File      .mp3   7.106010  320.090833  186.226939
# 6606  KAYTRANADA feat  File      .mp3   6.190234  320.104287  162.220408
# 6690  Mark Governor -  File      .mp3   5.916280  320.113501  155.036735
# 6716  Disco Lines - T  File      .mp3   5.840255  320.106163  153.048000
# 6798  The Guilty Plea  File      .mp3   5.342221  320.061250  140.016325
#
#       duration_minutes                                               Path  \
# 1377          7.919175  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 1447          7.554177  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 1495          7.294800  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 1657          6.887184  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2026          6.178000  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2153          6.019918  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2171          6.001633  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2315          5.801361  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2365          5.724299  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2643          5.384400  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 2940          5.054259  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 3020          4.957170  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 3310          4.702530  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 4766          3.873524  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 5140          3.681088  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 5314          3.600980  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 5355          3.584000  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 5800          3.344980  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6094          3.172000  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6176          3.124245  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6203          3.103782  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6606          2.703673  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6690          2.583946  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6716          2.550800  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6798          2.333605  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
#
#                          idt_title     idt_artist  \
# 1377                          None           None
# 1447                          None           None
# 1495                          None           None
# 1657                          None           None
# 2026                          None           None
# 2153                          None           None
# 2171                          None           None
# 2315                          None           None
# 2365                          None           None
# 2643                          None           None
# 2940                          None           None
# 3020                       Creeper      peachlyfe
# 3310  Dreams (Zoom and D.B.X. Mix)  Smokin' Beats
# 4766                          None           None
# 5140                  What Is Love       Dee-Lite
# 5314                          None           None
# 5355                          None           None
# 5800                          None           None
# 6094                          None           None
# 6176                          None           None
# 6203                          None           None
# 6606                          None           None
# 6690                  Stadium Rave  Mark Governor
# 6716                          None           None
# 6798                          None           None
#
#                                               idt_album idt_year idt_track  \
# 1377                                               None     None      None
# 1447                                               None     2023      None
# 1495                                               None     None      None
# 1657                                               None     None      None
# 2026                                               None     None      None
# 2153                                               None     None      None
# 2171                                               None     None      None
# 2315                                               None     None      None
# 2365                                               None     None      None
# 2643                                               None     None      None
# 2940                                               None     None      None
# 3020             Traxsource Essential Techno 2021-09-20     2021        15
# 3310  2step + Future Soul (Continuous DJ Mix by DJ S...     2010         9
# 4766                                               None     None      None
# 5140                                       World Clique     1990        06
# 5314                                               None     None      None
# 5355                                               None     None      None
# 5800                                               None     None      None
# 6094                                               None     None      None
# 6176                                               None     None      None
# 6203                                               None     None      None
# 6606                                               None     None      None
# 6690                                           Club Mix     1998         7
# 6716                                               None     None      None
# 6798                                               None     None      None
#
#                         idt_genre  \
# 1377                         None
# 1447                         None
# 1495                         None
# 1657                         None
# 2026                         None
# 2153                         None
# 2171                         None
# 2315                         None
# 2365                         None
# 2643                         None
# 2940                         None
# 3020                       Techno
# 3310  Rock;Rock & Roll/Rockabilly
# 4766                         None
# 5140                        House
# 5314                         None
# 5355                         None
# 5800                         None
# 6094                         None
# 6176                         None
# 6203                         None
# 6606                         None
# 6690                         None
# 6716                         None
# 6798                         None
#
#                                             idt_comment  idt_audio_offset  \
# 1377                                               None            1047.0
# 1447                                               None            1107.0
# 1495                                               None          159787.0
# 1657                                               None            1071.0
# 2026                                               None            1047.0
# 2153                                               None            1071.0
# 2171                                               None            1072.0
# 2315                                               None            1161.0
# 2365                                               None            1071.0
# 2643                                               None            1070.0
# 2940                                               None            1071.0
# 3020  https://1techno.org ==> everyday techno albums...            1413.0
# 3310                                                               2629.0
# 4766                                               None            1071.0
# 5140                                               None            1179.0
# 5314                                               None            1072.0
# 5355                                               None            1072.0
# 5800                                               None            1071.0
# 6094                                               None            1071.0
# 6176                                               None            1071.0
# 6203                                               None            1071.0
# 6606                                               None            1071.0
# 6690                                               None            1156.0
# 6716                                               None            1071.0
# 6798                                               None            1072.0
#
#         lufs         BPM        Size (MB) id  \
# 1377  -9.875  161.538082  18.126551628112793
# 1447  -8.386  141.261676  17.291193962097168
# 1495  -8.699  123.808564  16.849772453308105
# 1657  -9.260  125.963145  15.765528678894043
# 2026  -4.276   93.029242  14.142233848571777
# 2153 -15.840  150.524825  13.779520988464355
# 2171  -9.800  141.331330  13.738664627075195
# 2315 -11.470  116.830377  13.280363082885742
# 2365  -8.840  123.928552  13.103898048400879
# 2643 -11.625  125.990388  12.325849533081055
# 2940  -7.382  130.958503  11.570296287536621
# 3020  -7.534  145.312639  11.348526954650879
# 3310 -14.391  136.140983   10.76574420928955
# 4766 -11.271  126.059052   8.866813659667969
# 5140 -18.376  112.046504   8.427584648132324
# 5314 -10.694  117.563468   8.244006156921387
# 5355  -9.434  120.973021   8.205142974853516
# 5800  -7.607  129.041743   7.657072067260742
# 6094  -7.381  126.766176   7.262068748474121
# 6176  -7.801  126.366938    7.15284538269043
# 6203  -6.295  126.322283   7.106010437011719
# 6606  -7.839  113.418831   6.190234184265137
# 6690 -13.257  125.970207  5.9162797927856445
# 6716  -8.439  128.968735   5.840254783630371
# 6798  -6.539  131.282051   5.342221260070801
#
#                                         file_id
# 1377  Rennz - My Hous-MB-18.126551628112793.mp3
# 1447  Nelly Furtado --MB-17.291193962097168.mp3
# 1495  Micky More & An-MB-16.849772453308105.mp3
# 1657  Grant Nelson, S-MB-15.765528678894043.mp3
# 2026  RADIUM - 08 - B-MB-14.142233848571777.mp3
# 2153  Game Boys - Tet-MB-13.779520988464355.mp3
# 2171  Luz1e - Surge-1-MB-13.738664627075195.mp3
# 2315  Dolly Parton - -MB-13.280363082885742.mp3
# 2365  Cour T. - Black-MB-13.103898048400879.mp3
# 2643  Gay Marvine - M-MB-12.325849533081055.mp3
# 2940  Skrillex - Stil-MB-11.570296287536621.mp3
# 3020  15_peachlyfe_-_-MB-11.348526954650879.mp3
# 3310   063 - Smokin' B-MB-10.76574420928955.mp3
# 4766   DB7 - TETRIS TH-MB-8.866813659667969.mp3
# 5140   Dee-Lite - What-MB-8.427584648132324.mp3
# 5314   Fred again.. fe-MB-8.244006156921387.mp3
# 5355   Diplo feat. Eld-MB-8.205142974853516.mp3
# 5800   DNBN - Tetris m-MB-7.657072067260742.mp3
# 6094   Skrillex & BEAM-MB-7.262068748474121.mp3
# 6176    Skrillex & Bobb-MB-7.15284538269043.mp3
# 6203   Pete Tong & Bec-MB-7.106010437011719.mp3
# 6606   KAYTRANADA feat-MB-6.190234184265137.mp3
# 6690  Mark Governor --MB-5.9162797927856445.mp3
# 6716   Disco Lines - T-MB-5.840254783630371.mp3
# 6798   The Guilty Plea-MB-5.342221260070801.mp3

# %%
df_delete = df_duplicates # what data frames to erase

# %%
import os
from tqdm import tqdm
import pandas as pd

def delete_files_safely(df):
    """
    Safely delete the files listed in the 'Path' column of the dataframe.
    Bypass and print any errors encountered.
    """
    for file_path in tqdm(df['Path'], desc="Deleting files", unit="file"):
        try:
            os.remove(file_path)
        except Exception as e:
            print(f"Error deleting {file_path}: {e} : OPPENING FILES")

input_delete = input('ATTN:: To delete this files [y]   ')

if input_delete == 'y':
    delete_files_safely(df_delete)
# Out:
# ATTN:: To delete this files [y]   y
# Deleting files: 100%|█████████████████████████| 25/25 [00:01<00:00, 24.17file/s]

# %%
# # if subprocess fails does not delete show in Finder
# import subprocess

# def open_in_finder(file_paths):
#     """
#     Open the specified file paths in Finder.
#     """
#     for path in file_paths:
#         input('ATTN:: ABOUT TO OPEN locked files in FOLDER ')
#         subprocess.run(['open', '-R', path])
        
# open_in_finder(df_delete['Path'])

# %%
df_unique
# Out:
#                  Name  Type Extension  Size (MB)      bitrate    Duration  \
# 0     Eye_Nyam_Nam_Me  File     .aiff  94.898247  1411.795090  563.866667
# 1         At_Les.aiff  File     .aiff  93.252670  1412.021834  554.000000
# 2     Night_Clubbing-  File     .aiff  84.705515  1412.383684  503.093719
# 3     Never_Come_Back  File     .aiff  81.183163  1461.598861  465.937506
# 4     Let's_Dream-BY-  File     .aiff  79.475306  1411.889106  472.195147
# ...               ...   ...       ...        ...          ...         ...
# 6918   05 Trippin.m4a  File      .m4a   6.871672   373.478197  154.343039
# 6919     08 WU2NM.m4a  File      .m4a   6.124754   408.016358  125.921814
# 6920   04 So Cold.m4a  File      .m4a   5.882190   364.438726  135.395556
# 6921  01 Uuunnnnh.m4a  File      .m4a   5.719548   362.569778  132.330522
# 6922      07 Saxy.m4a  File      .m4a   5.445181   361.744255  126.270113
#
#       duration_minutes                                               Path  \
# 0             9.397778  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 1             9.233333  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 2             8.384895  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 3             7.765625  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# 4             7.869919  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_0...
# ...                ...                                                ...
# 6918          2.572384  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6919          2.098697  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6920          2.256593  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6921          2.205509  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
# 6922          2.104502  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_1...
#
#                                             idt_title  \
# 0     Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Blend)
# 1          At Les (Christian Smith's Hypnotica Remix)
# 2                 Night Clubbing (Marko Nastic Remix)
# 3                    Never Come Back (Four Tet Remix)
# 4                          Let's Dream (Original Mix)
# ...                                               ...
# 6918                                          Trippin
# 6919                                            WU2NM
# 6920                                          So Cold
# 6921                                         Uuunnnnh
# 6922                                             Saxy
#
#                                   idt_artist  \
# 0     Pat Thomas, Ebo Taylor, Henrik Schwarz
# 1                                 Carl Craig
# 2                                  Johnny D.
# 3                                    Caribou
# 4                                 Paco Osuna
# ...                                      ...
# 6918                         Edward Elecktro
# 6919                         Edward Elecktro
# 6920                         Edward Elecktro
# 6921                         Edward Elecktro
# 6922                         Edward Elecktro
#
#                                             idt_album    idt_year idt_track  \
# 0     Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Mixes)  2015-09-18         1
# 1                    At Les (Christian Smith Remixes)  2010-05-24         2
# 2                                   Night Clubbing EP        2015         2
# 3                                    Suddenly Remixes        2021         2
# 4                                           Long Play        2014         1
# ...                                               ...         ...       ...
# 6918                                   Heartbreak(er)        2015         5
# 6919                                   Heartbreak(er)        2015         8
# 6920                                       Surreality        2014         4
# 6921                                       Surreality        2014         1
# 6922                                       Surreality        2014         7
#
#                          idt_genre                            idt_comment  \
# 0                            House  engID3v1 CommentPurchased at Beatport
# 1     Techno (Peak Time / Driving)  engID3v1 CommentPurchased at Beatport
# 2                       Deep House  engID3v1 CommentPurchased at Beatport
# 3           Melodic House & Techno  engID3v1 CommentPurchased at Beatport
# 4                       Tech House  engID3v1 CommentPurchased at Beatport
# ...                            ...                                    ...
# 6918                   Alternative
# 6919                   Alternative
# 6920                    Electronic
# 6921                    Electronic
# 6922                    Electronic
#
#       idt_audio_offset    lufs         BPM       Size (MB) id  \
# 0                 46.0 -11.431  124.917720  94.89824676513672
# 1                 46.0  -8.679  126.938051  93.25267028808594
# 2                 46.0  -8.688  127.003650  84.70551490783691
# 3                 46.0 -10.715  128.999409  81.18316268920898
# 4                 46.0  -8.718  123.910002  79.47530555725098
# ...                ...     ...         ...                ...
# 6918               NaN -10.601  136.138626  6.871671676635742
# 6919               NaN -11.156  140.371620  6.124753952026367
# 6920               NaN -10.348  124.117294  5.882189750671387
# 6921               NaN  -9.960  131.113519  5.719548225402832
# 6922               NaN -10.540  125.897608  5.445180892944336
#
#                                         file_id
# 0     Eye_Nyam_Nam_Me-MB-94.89824676513672.aiff
# 1         At_Les.aiff-MB-93.25267028808594.aiff
# 2     Night_Clubbing--MB-84.70551490783691.aiff
# 3     Never_Come_Back-MB-81.18316268920898.aiff
# 4     Let's_Dream-BY--MB-79.47530555725098.aiff
# ...                                         ...
# 6918    05 Trippin.m4a-MB-6.871671676635742.m4a
# 6919      08 WU2NM.m4a-MB-6.124753952026367.m4a
# 6920    04 So Cold.m4a-MB-5.882189750671387.m4a
# 6921   01 Uuunnnnh.m4a-MB-5.719548225402832.m4a
# 6922       07 Saxy.m4a-MB-5.445180892944336.m4a
#
# [6898 rows x 20 columns]

# %% [markdown]
# # EXPORT

# %%
df_unique.to_pickle(f'0_coll.pkl')

# %%
#END

# %% [markdown]
# # CHECK COLLECTION - QUALITATIVE

# %%
# FILE SIZE , BITRATE and duration_minutes

# %%
exec(open(f"{direc}/_ms_EDA_1_numeric_var_graph.py",encoding="utf-8").read())
visualize_distribution(df, 'Size (MB)')

# %%
# bitrate

# %%
# bitrate

sorted_tracks = df.sort_values(by='bitrate', ascending=True)
print(sorted_tracks[['Name', 'bitrate']].head(3))  # top 10 loudest tracks
# Out:
#                  Name     bitrate
# 1535  07 - azoto - sa  320.002444
# 1801  Britney (320kbp  320.003171
# 1582  I Need You (Peg  320.003367

# %%
visualize_distribution(df, 'bitrate')

# %%
# duration

# %%
# DURATION
sorted_tracks = df.sort_values(by='duration_minutes', ascending=True)
print(sorted_tracks[['Name', 'duration_minutes']].head(3))  # top 10 loudest tracks

#
visualize_distribution(df, 'duration_minutes')
# Out:
#                  Name  duration_minutes
# 6844  13_Gramatik_Now          2.001415
# 6717  fr_pieg-14_03_2          2.003290
# 6718  04-Unhappy girl          2.003290

# %%
# (EDA)- exploratory data analysis -  COLLECTION - QUALITATIVE

# %%
# lufs

# %%
sorted_tracks = df.sort_values(by='lufs', ascending=False)
print(sorted_tracks[['Name', 'lufs']].head(9))  # top 10 loudest tracks


sorted_tracks_a = df.sort_values(by='lufs', ascending=True)
print('\n',sorted_tracks_a[['Name', 'lufs']].head(3))  # top 10 loudest tracks

visualize_distribution(df, 'lufs')
# Out:
#                  Name    lufs
# 361   Jade Cicada - B  90.905
# 986   Deep Deep Maste  90.432
# 1018  Pulse Master.wa  89.979
# 334   Jade Cicada - B  89.745
# 754   tokyo drift rem  89.729
# 802   AEOLUS - BATTLE  89.718
# 816   AEOLUS - DESiRE  89.692
# 530   Detroit Flex Ma  89.572
# 807   AEOLUS & GiN-B   89.553
#
#                   Name    lufs
# 1087  WATUPDOE FT LOL -26.557
# 5111  Pepino Di Capi  -24.320
# 6880  04 Domo Genesis -23.400

# %%
# genre

# %%
dis = df['idt_genre'].value_counts()
dis.head(40)
# Out:
# Electro                           771
# Rock                              689
# Rap US                            267
# House                             224
# Chillwave                         217
# Pop                               202
# Rap Français                      170
# Electro-Pop                       153
# Tech House                        116
# Deep House                        103
# Other                              80
# Reggae                             80
# Techno                             68
# Electronic                         59
# Rap                                56
# Hip-Hop                            49
# Afro House                         44
# B.O.                               35
# Variété                            33
# Electronica                        30
# Nu Disco / Disco                   29
# Melodic House & Techno             27
# Footwork                           25
# R&B                                25
# Techno (Peak Time / Driving)       24
# B-More                             24
# Bass                               23
# Blues                              22
# Soul                               21
# Techno (Raw / Deep / Hypnotic)     21
# Jazz                               21
# Minimal / Deep Tech                18
# Trip-Hop/PBR&B/Art-Pop             17
# Dance / Electro Pop                17
# Dance                              15
# Booty Bass                         15
# Country                            14
# Indie Dance                        14
# DJ Tools                           14
# rave                               12
# Name: idt_genre, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you've loaded your df_all from somewhere

# Compute the counts
idt_genre_counts = dis.head(40)

# Plot the counts
plt.figure(figsize=(10,6))
idt_genre_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Distribution of idt_genre')
plt.tight_layout()
plt.show()

# %%
# year

# %%
# END - follow by
