# %%
exec(open(f"/Users/yerik/_apple_source/PY/GLOBAL/_1_paths.py",encoding="utf-8").read()) #paths
direc=curr_direc
# Out:
# ###################################################################################################### - HI
# ######################################################################################################
# ----------------------------------------------------------------------------------------------------->
# - PY ---------------------------------------------------------------------------- GLOBAL/_1_paths.py >
# - MOST COMMON :: <desk_path>:<docs_path>:<down_path>::----------------------------------------------->
# ----------------------------------------------------------------------------------------------------->
# ********************************************  > No Extension *
# 									 -*- [ .DS_Store ]
#
# ********************************************  > Directory *
# 									 -*- [ .ipynb_checkpoints ]
# 									 -*- [ playlists ]
# 									 -*- [ stems ]
#
# ********************************************  > .pkl *
# 									 -*- [ 0_coll-Copy1.pkl ]
# ...

# %%
## ATTN FOR OTHER DIRECTORIES - just uncomment this *******************

path_songs = f'/Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5_all_misc/22-23_ripped_ms_RIP' 
exec(open(f"{direc}/ms_1_music_files.py",encoding="utf-8").read()) #paths
df_AU_ALL =df_AU.copy()
df_AU_ALL.head()
# Out:
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: my_folder_path
# ***df*** will be returned having ::: 1191  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 5261.238
# Grand Total Size in Bytes: 5516808321.000
# Grand Total Size in GB: 5.138
#
#  FREQUENCY TABLE:::
#
#     Extension  frequency  total_size_in_mb
# 0      .mp3       1191       5261.238404
#
#
#  FREQUENCY TABLE of
#
#  ['.m4a', '.mp3', '.MP3', '.Mp3', '.wav', '.WAV', '.flac', '.FLAC', '.aac', '.ogg', '.wma', '.au', '.aif', '.aiff']
#
#
#
# total music files :  1191
#
#    Extension  frequency  total_size_in_mb
# 0      .mp3       1191       5261.238404
#
#  ATTN ->
# DF with ALL files ::: df :1191:: &
# DF with just audio_extensions ::: df_AU ::1191:
#                 Name  Type                                               Path  \
# 2    RÜFÜS DU SOL   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# ...

# %%
    ################################################                                       2)  LUFS
exec(open(f"{direc}/_ms_pl_info_2_all_LUFS.py",encoding="utf-8").read())
df['lufs'] = compute_lufs_for_paths(df['Path'])
    ################################################                                       3)  BPM
exec(open(f"{direc}/_ms_pl_info_3_BPM.py",encoding="utf-8").read())
df['BPM'] = [compute_bpm(x) if x.endswith(tuple(audio_extensions)) else None for x in tqdm(df['Path'], desc="Computing BPM")]
# Out:
# Computing LUFS:  91%|███████████████████  | 1081/1191 [22:08<00:28,  3.81file/s]
# Error processing /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5_all_misc/22-23_ripped_ms_RIP/._download 3.mp3: Decoding failed. ffmpeg returned error code: 1
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
df_pl_ALL = df[~df['Name'].str.startswith('._')].copy()
# Out:
#                  Name  Type  \
# 2     RÜFÜS DU SOL   File
# 3     FOALS - The Run  File
# 763    download 3.mp3  File
# 765      enanitos.mp3  File
# 761      download.mp3  File
# ...               ...   ...
# 851   ._PREMIERE : Pa  File
# 846   ._Spencer Parke  File
# 841   ._onlymp3.to -   File
# 838   ._onlymp3.to -   File
# 1190  ._Mark Funk, Da  File
#
#                                                    Path Extension  Size (MB)  \
# 2     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3  13.283951
# 3     /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3  13.072848
# 763   /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3  11.467153
# 765   /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3  11.467153
# 761   /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3  11.467153
# ...                                                 ...       ...        ...
# 851   /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...      .mp3   0.003906
# ...

# %%
# Re write variables
# BPM
df_pl_ALL['BPM_print'] = np.floor(df_pl_ALL['BPM'] * 10) / 10
df_pl_ALL['BPM_print'] = df_pl_ALL['BPM_print'].astype(str).str.replace('.', '_')
# LUFS
df_pl_ALL['LUFS_print'] = np.floor(df_pl_ALL['lufs'] * 10) / 10
df_pl_ALL['LUFS_print'] = df_pl_ALL['LUFS_print'].astype(str).str.replace('.', '_')

# NEW NAME
df_pl_ALL['Name'] = df_pl_ALL['Name'].str[:20]

df_pl_ALL['new_name'] = df_pl_ALL['Name'] + '_BPM_' + df_pl_ALL['BPM_print'].astype(str) + '_LUFS_' + df_pl_ALL['LUFS_print'].astype(str) + '_pl_RIP'
# Out:
# /var/folders/r1/gtmyxpws2836627xn7_9c5380000gn/T/ipykernel_75449/2302851237.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_pl_ALL['BPM_print'] = df_pl_ALL['BPM_print'].astype(str).str.replace('.', '_')
# /var/folders/r1/gtmyxpws2836627xn7_9c5380000gn/T/ipykernel_75449/2302851237.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_pl_ALL['LUFS_print'] = df_pl_ALL['LUFS_print'].astype(str).str.replace('.', '_')

# %%
df_pl_ALL
# Out:
#                 Name  Type                                               Path  \
# 2    RÜFÜS DU SOL   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 3    FOALS - The Run  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 763   download 3.mp3  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 765     enanitos.mp3  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 761     download.mp3  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# ..               ...   ...                                                ...
# 756  Chase-112438361  File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 757  Toy of -  Dont   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 758  Tapesh & Mr. J   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 759  IV100 - Âme -   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
# 760  IV100 - Âme -   File  /Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5...
#
# ...

# %%
# Copy with new name
#dest_folder = f'/Volumes/HD_back_UP/ALL_MUSIC/Music_back_up/_5_all_misc/usb_EMERGENCY/pl_RIP_22-23'

# %%
import os
import shutil
import pandas as pd

# Sample data (you'd have your actual data here)

# Destination folder

if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)

# Iterate over DataFrame rows
for index, row in df_pl_ALL.iterrows():
    source_path = row['Path']
    dest_path = os.path.join(dest_folder, row['new_name'] + os.path.splitext(source_path)[-1])  # Append the file extension

    if os.path.exists(source_path):
        shutil.copy2(source_path, dest_path)  # Copy and rename the file

print("Files copied successfully!")
# Out:
# Files copied successfully!
